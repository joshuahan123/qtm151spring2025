# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print("Joshua Han")

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", <br>
# "pandas", "statsmodels.api" and "statsmodels.formula.api"

# %%
# Write your answer here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# Read the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting <br>
# to get a sense of its content

# %%
# Write your own code
players = pd.read_csv("data_quiz/fifa23_players_basic.csv")

players
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Preferred Foot  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            Left
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...           Right
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...           Right
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...           Right
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...           Right
# ...                                                 ...  ...             ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...           Right
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...           Right
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...           Right
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...           Right
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            Left
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 18534                 3            2                         1
# 18535                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                  ...
# 18534                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# ...                       ...                          ...
# 18534                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 0                     Low                 Low
# 1                  Medium              Medium
# 2                    High              Medium
# 3                    High                High
# 4                    High                 Low
# ...                   ...                 ...
# 18534              Medium              Medium
# 18535              Medium              Medium
# 18536                High              Medium
# 18537              Medium              Medium
# 18538              Medium              Medium
#
# [18539 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Use queries
#
# <font size = "3">
#
# - Browse the dataset and search for the height variable in cm (centimeters).
#
# - Subset the players whose value of the height variable is above 175 <br>
# and store it in a new dataset
# - How many players are above this height threshold?
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# and when the value is a string. See example provided.

# %%
# Write your own code

# Example: The following code filters whether 
# observations for which `On Loan` is equal to yes
# dataset.query(' `On Loan` == "YES" ')
# Note: be careful with using backward quotations ` here.
# Now apply this to your own example, and calculate the total number of observations.
height = 175

tall_players = players.query("`Height(in cm)` > 175")

tall_players.sum()
# Out:
# Unnamed: 0                                                             135465756
# Known As                       K. BenzemaR. LewandowskiK. De BruyneK. MbappéT...
# Full Name                      Karim BenzemaRobert LewandowskiKevin De Bruyne...
# Overall                                                                   965672
# Potential                                                                1040592
# Value(in Euro)                                                       41945283966
# Positions Played               CF,STSTCM,CAMST,LWGKGKSTCBSTLW,LMCDMGKGKCDM,RB...
# Best Position                  CFSTCMSTGKGKSTCBSTLWCDMGKGKCDMGKCBSTGKLBCBGKGK...
# Nationality                    FrancePolandBelgiumFranceBelgiumGermanyPortuga...
# Image Link                     https://cdn.sofifa.net/players/165/153/23_60.p...
# Age                                                                       371602
# Height(in cm)                                                            2697033
# Weight(in kg)                                                            1129425
# TotalStats                                                              23083084
# BaseStats                                                                5226883
# Club Name                      Real Madrid CFFC BarcelonaManchester CityParis...
# Wage(in Euro)                                                          131175200
# Release Clause                                                       74022513899
# Club Position                  CFSTCMSTGKGKSUBCBSTLWSUBGKGKCDMGKCBSTGKLBCBSUB...
# Contract Until                 2023202520252024202620242023202520242025202620...
# Club Jersey Number             9917711741071813316139997511822163125116662626...
# Joined On                                                               29604494
# On Loan                        ------------------------------------YES-------...
# Preferred Foot                 RightRightRightRightLeftRightRightRightRightRi...
# Weak Foot Rating                                                           42762
# Skill Moves                                                                33149
# International Reputation                                                   15978
# National Team Name             FrancePolandBelgiumFranceBelgiumGermanyPortuga...
# National Team Image Link       https://cdn.sofifa.net/flags/fr.pnghttps://cdn...
# National Team Position         STSTRFSTGKGKSTCBST----CDM-CBSTGKRB--SUB-CBSUB-...
# National Team Jersey Number    19971011749----6-492120--12-216-113116-3-82117...
# Attacking Work Rate            MediumHighHighHighMediumMediumHighMediumHighHi...
# Defensive Work Rate            MediumMediumHighLowMediumMediumLowHighHighMedi...
# player_classifcation           Top PerformerTop PerformerTop PerformerTop Per...
# dtype: object

# %% [markdown]
# <font size = "5">
#
# (b) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# The varable "Contract Until" shows the date in which a player's contract will expire.
# - Use ".sort_values()" to order the "Contract Until" column <br>
# from later dates to earlier dates.
# - Get a subset with the 5 players in the dataset <br>
# whose contracts will expire later.
# - From this subset, display the names and year in which the contract will expire.
#
# Your output should look something like this:
#
# | Full Name | Contract Until |
# | -------- | ------- |
# | José Luis García Vayá | 2032
# | José Luis García Vayá | 2032
# | Jon Moncayola Tollar | 2031
# | Jon Moncayloa Tollar | 2031
# | Josip Sutalo | 2028
# | Aurelien Tchouaméni | 2028

# %%
# Write your own code
players["`Contract Until Numeric`"] = pd.to_numeric(players["`Contract Until`"])
players.sort_values(by = "`Contract Until Numeric`", ascending = False)

players.iloc[0:5, :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/f9/n9s6gwvj3gn4zkp0fryrstzc0000gn/T/ipykernel_3166/3756318832.py in ?()
#       1 # Write your own code
#       2 #players["`Contract Until Numeric`"] = pd.to_numeric(players["`Contract Until`"])
# ----> 3 players.sort_values(by = "`Contract Until Numeric`", ascending = False)
#       4
#       5 players.iloc[0:5, :]
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: '`Contract Until Numeric`'

# %% [markdown]
# <font size = "5">
#
# (c) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "TotalStats"
# - If "TotalStats > 85", classification = "Top Performer"
# - If "TotalStats <= 85", classification = "Non Top-Performer"
# - The function returns "classification"
#
# Step 2:
# - Extract the column "TotalStats" in the dataset <br>
# - Create a new variable called "player_classification" <br>
# to assign each player to the correct classification
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def function(TotalStats):
    if TotalStats > 85:
        classification = "Top Performer"
    else:
        classification = "Non Top-Performer"
    return classification

players["player_classifcation"] = players["TotalStats"].apply(function)

players
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...
# ...                                                 ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 18534                 3            2                         1
# 18535                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                  ...
# 18534                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#       National Team Position  National Team Jersey Number  \
# 0                         RW                           10
# 1                         ST                           19
# 2                         ST                            9
# 3                         RF                            7
# 4                         ST                           10
# ...                      ...                          ...
# 18534                      -                            -
# 18535                      -                            -
# 18536                      -                            -
# 18537                      -                            -
# 18538                      -                            -
#
#        Attacking Work Rate Defensive Work Rate player_classifcation
# 0                      Low                 Low        Top Performer
# 1                   Medium              Medium        Top Performer
# 2                     High              Medium        Top Performer
# 3                     High                High        Top Performer
# 4                     High                 Low        Top Performer
# ...                    ...                 ...                  ...
# 18534               Medium              Medium        Top Performer
# 18535               Medium              Medium        Top Performer
# 18536                 High              Medium        Top Performer
# 18537               Medium              Medium        Top Performer
# 18538               Medium              Medium        Top Performer
#
# [18539 rows x 34 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Regression function
#
# <font size = "3">
#
# - Run a regression of "Overall" (left-hand side) on "Age" (right-hand side)
# - What are the values of the coefficients?
#
# [HINT: Use the commands ```smf.ols()``` and ```.fit()``` and ```.params``` <br>
# from Lecture 11 ]

# %%
# Write your own code
model = smf.ols(formula = 'Overall ~ Age', data = players)
results = model.fit()

list = results.params()
print(list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 5
#       2 model = smf.ols(formula = 'Overall ~ Age', data = players)
#       3 results = model.fit()
# ----> 5 list = model.params()
#       6 print(list)
#
# AttributeError: 'OLS' object has no attribute 'params'

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Store the total number of rows of the dataset in a variable called ```n``` <br>
# - Create a new variable called ```random_var``` drawn from a <br>
# uniform distribution between 0 and 1 with size ```n```
# - Use .query() to subset all observations with ```random_var <0.4```.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with ```random_var >= 0.4```.<br>
# store it in a new dataset called "data1"
#
# [HINT: See Lecture 2 for how to generate a uniform random variable]

# %%
# Write your own code
n = 18,539
random_var = np.random.uniform(low=0, high=1, size=n)

random_var

data0 = players.query("random_var < 0.4")
data1 = players.query("random_var >= 0.4")
# Out:
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[43], line 7
#     data0 = players.query("random_var < @0.4")
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4823 in query
#     res = self.eval(expr, **kwargs)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4949 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/eval.py:336 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:809 in __init__
#     self.terms = self.parse()
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:828 in parse
#     return self._visitor.visit(self.expr)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:408 in visit
#     raise e
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:404 in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File /opt/anaconda3/lib/python3.12/ast.py:52 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
#     random_var <__pd_eval_local_0.4
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping scatter plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display a scatter plot of "Potential" vs "Age" for "data0" using <br>
# ```plt.scatter()```
# - Display a scatter plot of "Potential" vs "Age" for "data1" overlapping <br>
# on top of the previous one
# - You will need to add a legend, label the axes, and the title
# - To get full points, plot the scatter plot with the option  ```alpha = 0.5```, e.g. <br>
#  ``` plt.hist(x = ..., y = ... , alpha = 0.5) ``` <br>
#  Make sure to substitute the corresponding "x" and "y" vectors instead of ```...``` <br>
# (The alpha option sets the transparency of the scatter plot)
#
# Note: The goal of this question is to illustrate that random <br>
# assignment will produce very similar scatter plots for each variable

# %%
# Write your own code
plt.scatter(x=data0["Potential"], y=data0["Age"])
plt.scatter(x=data1["Potential"], y=data1["Age"])

plt.title("Potential vs Age for Players")
plt.xlabel("Potential")
plt.ylabel("Age")
plt.legend(labels = data_number,
           title = "Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 # Write your own code
# ----> 2 plt.scatter(x=data0["Potential"], y=data0["Age"])
#       3 plt.scatter(x=data1["Potential"], y=data1["Age"])
#       5 plt.title("Potential vs Age for Players")
#
# NameError: name 'data0' is not defined
